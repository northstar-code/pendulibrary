# %%
from pendulibrary.plotters import plot_timeline_grid, gui

int_tol = 1e-14

# %%
# %load_ext autoreload
# %autoreload 2

# %%
gui(
    "../database",
    targ_tol=1e-7,
    int_tol=1e-14,
    n_time=500,
    density=5,
    max_iter=25,
    debug=False,
)
