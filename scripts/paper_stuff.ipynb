# %%
from pendulibrary.plotters import plot_timeline_grid, gui, animate_family
from os import listdir
from os.path import exists
from threading import Thread

int_tol = 1e-14

# %%
# %load_ext autoreload
# %autoreload 2

# %%
gui(
    "../database",
    targ_tol=1e-7,
    int_tol=1e-14,
    n_time=500,
    density=5,
    max_iter=25,
    debug=False,
)

# %% [markdown]
# # Animations

# %%
procs = []
fnames = [f.removesuffix(".npz") for f in listdir("../database/")]
fnames.remove("DDsp")
fnames.remove("DDlp")
fnames.remove("UD")
fnames.remove("DU")

# %%
# animate_family("DDsp-P2e", 100, 20, 200, 5, 1.5, len_bounds=(0.0, 0.4))

# %%
# procs = []
# for fname in fnames:
#     try:
#         animate_family(fname, 100, 20, 200, 5, 1.5)
#     except RuntimeError:
#         print("ERROR ON ", fname)

# %%
# procs = []
# for fname in fnames[:10]:
#     p = Thread(target=animate_family, args=(fname, 90, 20, 200, 5, 2.5))
#     procs.append(p)
# for proc in procs:
#     proc.start()
# for proc in procs:
#     proc.join()
