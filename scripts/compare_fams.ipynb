# %%
# %load_ext autoreload
# %autoreload 2


import numpy as np
from os import listdir
from pendulibrary.plotters import compare_fast
int_tol = 1e-14

# %%
fnames = [f.removesuffix(".npz") for f in listdir("../database") if "DDsp-P4" in f]

# %%
colormap = "hsv"
directory = "../database/"
data_test = np.load("../database/DDsp-P4a.npz")
periods = data_test['periods']
hamiltonians = data_test['hamiltonians']

# %%
compare_fast(periods, hamiltonians, fnames)
